# %% [markdown]
# 1. Importing Pandas Library

# %%
import pandas as pd

# %% [markdown]
# 2. Reading Study Abroad Dataset CSV File

# %%
df = pd.read_csv("study_abroad.csv")

# %% [markdown]
# 3. Checking DataFrame(Dataset) Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         150 non-null    int64
#  1   Country                      150 non-null    object
#  2   Number_of_Indian_Students    150 non-null    int64
#  3   Tuition_Fee_USD              150 non-null    int64
#  4   Living_Cost_USD              150 non-null    int64
#  5   Average_Rent_USD             150 non-null    int64
#  6   Transportation_Cost_USD      150 non-null    int64
#  7   Total_Annual_Cost_USD        150 non-null    int64
#  8   Student_Visa_Applications    150 non-null    int64
#  9   Student_Visa_Approvals       150 non-null    int64
#  10  Student_Visa_Rejections      150 non-null    int64
#  11  Visa_Acceptance_Rate         150 non-null    float64
#  12  Average_Graduate_Salary_USD  150 non-null    int64
# ...

# %% [markdown]
# 4. Checking DataFrame Description

# %%
df.describe()
# Out:
#               Year  Number_of_Indian_Students  Tuition_Fee_USD  \
# count   150.000000                 150.000000       150.000000
# mean   2020.500000               79725.760000     25703.506667
# std       2.881904               40590.307612     10414.351115
# min    2016.000000                4891.000000      6363.000000
# 25%    2018.000000               41371.500000     15421.000000
# 50%    2020.500000               90458.500000     27374.000000
# 75%    2023.000000              111116.250000     34200.000000
# max    2025.000000              145641.000000     44521.000000
#
#        Living_Cost_USD  Average_Rent_USD  Transportation_Cost_USD  \
# count       150.000000        150.000000               150.000000
# mean      13498.346667       7674.333333              1518.433333
# std        5100.139440       2716.212483               562.811881
# min        5113.000000       2751.000000               519.000000
# ...

# %% [markdown]
# 5. Checking for the Missing Values

# %%
df.isnull().sum()
# Out:
# Year                           0
# Country                        0
# Number_of_Indian_Students      0
# Tuition_Fee_USD                0
# Living_Cost_USD                0
# Average_Rent_USD               0
# Transportation_Cost_USD        0
# Total_Annual_Cost_USD          0
# Student_Visa_Applications      0
# Student_Visa_Approvals         0
# Student_Visa_Rejections        0
# Visa_Acceptance_Rate           0
# Average_Graduate_Salary_USD    0
# Graduate_Employment_Rate       0
# Post_Study_Work_Visa_Months    0
# PR_Availability                0
# Number_of_Top_Universities     0
# Average_QS_Ranking             0
# Scholarships_Available         0
# GDP_Per_Capita_USD             0
# Inflation_Rate                 0
# dtype: int64

# %% [markdown]
# 6. Checking For Duplicates Values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 7. Exporting Latest - Cleaned CSV File

# %%
df.to_csv("study_abroad_cleaned.csv")
